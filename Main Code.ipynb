# %%
#Dependencies
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import numpy as np
import time
import os
from scipy.stats import linregress
import scipy.stats as stats
from scipy.stats import spearmanr
import csv

# %%
#Importing Data
data = pd.read_csv("../GDPvsCOVID/Resources/covid.csv")
data
# Out:
#      iso_code continent           location last_updated_date  total_cases  \
# 0         AFG      Asia        Afghanistan        2021-10-19     155801.0
# 1    OWID_AFR       NaN             Africa        2021-10-19    8444411.0
# 2         ALB    Europe            Albania        2021-10-19     178804.0
# 3         DZA    Africa            Algeria        2021-10-19     205453.0
# 4         AND    Europe            Andorra        2021-10-19      15369.0
# ..        ...       ...                ...               ...          ...
# 219       WLF   Oceania  Wallis and Futuna        2021-10-18          NaN
# 220  OWID_WRL       NaN              World        2021-10-19  241568522.0
# 221       YEM      Asia              Yemen        2021-10-19       9575.0
# 222       ZMB    Africa             Zambia        2021-10-19     209549.0
# 223       ZWE    Africa           Zimbabwe        2021-10-19     132405.0
#
#      new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0         25.0              28.857        7247.0         1.0
# 1       6054.0            6225.429      215909.0       240.0
# 2        616.0             448.571        2841.0        12.0
# 3         89.0              94.714        5875.0         2.0
# 4          2.0               8.857         130.0         0.0
# ..         ...                 ...           ...         ...
# 219        NaN                 NaN           NaN         NaN
# 220   436256.0          409047.000     4913106.0      8012.0
# 221       19.0              23.286        1813.0         6.0
# 222       13.0              21.857        3658.0         0.0
# 223       37.0              55.571        4659.0         1.0
#
#      new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 0                  2.429  ...             NaN           NaN
# 1                215.286  ...             NaN           NaN
# 2                  8.286  ...           7.100        51.200
# 3                  2.286  ...           0.700        30.400
# 4                  0.000  ...          29.000        37.800
# ..                   ...  ...             ...           ...
# 219                  NaN  ...             NaN           NaN
# 220             6784.429  ...           6.434        34.635
# 221                3.714  ...           7.600        29.200
# 222                0.571  ...           3.100        24.700
# 223                2.000  ...           1.600        30.700
#
#      handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                    37.746                       0.500            64.83
# 1                       NaN                         NaN              NaN
# 2                       NaN                       2.890            78.57
# 3                    83.741                       1.900            76.88
# 4                       NaN                         NaN            83.73
# ..                      ...                         ...              ...
# 219                     NaN                         NaN            79.94
# 220                  60.130                       2.705            72.58
# 221                  49.542                       0.700            66.12
# 222                  13.938                       2.000            63.89
# 223                  36.791                       1.700            61.49
#
#      human_development_index  excess_mortality_cumulative_absolute  \
# 0                      0.511                                   NaN
# 1                        NaN                                   NaN
# 2                      0.795                                   NaN
# 3                      0.748                                   NaN
# 4                      0.868                                   NaN
# ..                       ...                                   ...
# 219                      NaN                                   NaN
# 220                    0.737                                   NaN
# 221                    0.470                                   NaN
# 222                    0.584                                   NaN
# 223                    0.571                                   NaN
#
#      excess_mortality_cumulative  excess_mortality  \
# 0                            NaN               NaN
# 1                            NaN               NaN
# 2                            NaN               NaN
# 3                            NaN               NaN
# 4                            NaN               NaN
# ..                           ...               ...
# 219                          NaN               NaN
# 220                          NaN               NaN
# 221                          NaN               NaN
# 222                          NaN               NaN
# 223                          NaN               NaN
#
#      excess_mortality_cumulative_per_million
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 219                                      NaN
# 220                                      NaN
# 221                                      NaN
# 222                                      NaN
# 223                                      NaN
#
# [224 rows x 65 columns]

# %%
#reducing and cleaning data

#pulled the rows we are going to use
cut_data = data[["continent", "location", "population","median_age", "gdp_per_capita",
                 "total_cases","total_vaccinations", "total_deaths", "diabetes_prevalence"]]

#since we pulled only the rows we plan to use, we dropped all rows with blanks
clean_data = cut_data.dropna()
clean_data
# Out:
#          continent             location  population  median_age  \
# 2           Europe              Albania   2872934.0        38.0
# 5           Africa               Angola  33933611.0        16.8
# 7    North America  Antigua and Barbuda     98728.0        32.1
# 8    South America            Argentina  45605823.0        31.9
# 9             Asia              Armenia   2968128.0        35.7
# ..             ...                  ...         ...         ...
# 215        Oceania              Vanuatu    314464.0        23.1
# 217  South America            Venezuela  28704947.0        29.0
# 218           Asia              Vietnam  98168829.0        32.6
# 222         Africa               Zambia  18920657.0        17.7
# 223         Africa             Zimbabwe  15092171.0        19.6
#
#      gdp_per_capita  total_cases  total_vaccinations  total_deaths  \
# 2         11803.431     178804.0           1842661.0        2841.0
# 5          5819.495      63197.0           5224697.0        1678.0
# 7         21490.943       3918.0            101390.0          95.0
# 8         18933.907    5274766.0          56217372.0      115737.0
# 9          8787.580     284237.0            514241.0        5842.0
# ..              ...          ...                 ...           ...
# 215        2921.909          4.0             87583.0           1.0
# 217       16745.022     395223.0          16127242.0        4748.0
# 218        6171.884     870255.0          64992488.0       21344.0
# 222        3689.251     209549.0            851990.0        3658.0
# 223        1899.775     132405.0           5742988.0        4659.0
#
#      diabetes_prevalence
# 2                  10.08
# 5                   3.94
# 7                  13.17
# 8                   5.50
# 9                   7.11
# ..                   ...
# 215                12.02
# 217                 6.47
# 218                 6.00
# 222                 3.94
# 223                 1.82
#
# [160 rows x 9 columns]

# %%
#Summary Table
summary = clean_data.groupby("continent").agg({"location":"count",
                                    "population":"sum",
                                    "median_age":"mean",
                                    "gdp_per_capita":"mean",
                                    "total_cases":"sum",
                                    "total_vaccinations": "sum",
                                    "total_deaths":"sum",
                                    "diabetes_prevalence":"mean"})

summary = summary.rename(columns={"location":"No. of Countries",
                                 "population":"Population",
                                  "median_age":"Median Age",
                                 "gdp_per_capita": "Average GDP/capita",
                                 "total_cases":"Total Cases",
                                 "total_vaccinations":"Total Vaccinations",
                                 "total_deaths":"Total Deaths",
                                 "diabetes_prevalence":"Diabetes Prevalance"})

summary.style.format({"No. of Countries":'{:,.0f}',"Total Vaccinations":'{:,.0f}',"Population":'{:,.0f}',
                      "Total Cases":'{:,.0f}', "Average GDP/capita":'{:,.0f}',"Total Deaths":'{:,.0f}',
                     "Diabetes Prevalance":'{:,.0f}%', "Median Age":'{:,.0f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_cf3ac_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >No. of Countries</th>        <th class="col_heading level0 col1" >Population</th>        <th class="col_heading level0 col2" >Median Age</th>        <th class="col_heading level0 col3" >Average GDP/capita</th>        <th class="col_heading level0 col4" >Total Cases</th>        <th class="col_heading level0 col5" >Total Vaccinations</th>        <th class="col_heading level0 col6" >Total Deaths</th>        <th class="col_heading level0 col7" >Diabetes Prevalance</th>    </tr>    <tr>        <th class="index_name level0" >continent</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cf3ac_level0_row0" class="row_heading level0 row0" >Africa</th>
#                         <td id="T_cf3ac_row0_col0" class="data row0 col0" >45</td>
#                         <td id="T_cf3ac_row0_col1" class="data row0 col1" >1,156,530,029</td>
#                         <td id="T_cf3ac_row0_col2" class="data row0 col2" >21</td>
#                         <td id="T_cf3ac_row0_col3" class="data row0 col3" >5,768</td>
#                         <td id="T_cf3ac_row0_col4" class="data row0 col4" >8,058,302</td>
#                         <td id="T_cf3ac_row0_col5" class="data row0 col5" >157,621,694</td>
#                         <td id="T_cf3ac_row0_col6" class="data row0 col6" >203,529</td>
#                         <td id="T_cf3ac_row0_col7" class="data row0 col7" >5%</td>
#             </tr>
#             <tr>
#                         <th id="T_cf3ac_level0_row1" class="row_heading level0 row1" >Asia</th>
#                         <td id="T_cf3ac_row1_col0" class="data row1 col0" >40</td>
#                         <td id="T_cf3ac_row1_col1" class="data row1 col1" >4,466,810,919</td>
#                         <td id="T_cf3ac_row1_col2" class="data row1 col2" >31</td>
#                         <td id="T_cf3ac_row1_col3" class="data row1 col3" >23,785</td>
#                         <td id="T_cf3ac_row1_col4" class="data row1 col4" >76,984,446</td>
#                         <td id="T_cf3ac_row1_col5" class="data row1 col5" >4,486,174,180</td>
#                         <td id="T_cf3ac_row1_col6" class="data row1 col6" >1,123,302</td>
#                         <td id="T_cf3ac_row1_col7" class="data row1 col7" >10%</td>
#             </tr>
#             <tr>
#                         <th id="T_cf3ac_level0_row2" class="row_heading level0 row2" >Europe</th>
#                         <td id="T_cf3ac_row2_col0" class="data row2 col0" >39</td>
#                         <td id="T_cf3ac_row2_col1" class="data row2 col1" >745,267,118</td>
#                         <td id="T_cf3ac_row2_col2" class="data row2 col2" >42</td>
#                         <td id="T_cf3ac_row2_col3" class="data row2 col3" >33,917</td>
#                         <td id="T_cf3ac_row2_col4" class="data row2 col4" >61,908,118</td>
#                         <td id="T_cf3ac_row2_col5" class="data row2 col5" >823,054,791</td>
#                         <td id="T_cf3ac_row2_col6" class="data row2 col6" >1,256,502</td>
#                         <td id="T_cf3ac_row2_col7" class="data row2 col7" >6%</td>
#             </tr>
#             <tr>
#                         <th id="T_cf3ac_level0_row3" class="row_heading level0 row3" >North America</th>
#                         <td id="T_cf3ac_row3_col0" class="data row3 col0" >20</td>
#                         <td id="T_cf3ac_row3_col1" class="data row3 col1" >580,768,767</td>
#                         <td id="T_cf3ac_row3_col2" class="data row3 col2" >31</td>
#                         <td id="T_cf3ac_row3_col3" class="data row3 col3" >17,122</td>
#                         <td id="T_cf3ac_row3_col4" class="data row3 col4" >53,324,535</td>
#                         <td id="T_cf3ac_row3_col5" class="data row3 col5" >630,178,538</td>
#                         <td id="T_cf3ac_row3_col6" class="data row3 col6" >1,094,073</td>
#                         <td id="T_cf3ac_row3_col7" class="data row3 col7" >11%</td>
#             </tr>
#             <tr>
#                         <th id="T_cf3ac_level0_row4" class="row_heading level0 row4" >Oceania</th>
#                         <td id="T_cf3ac_row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_cf3ac_row4_col1" class="data row4 col1" >31,866,222</td>
#                         <td id="T_cf3ac_row4_col2" class="data row4 col2" >32</td>
#                         <td id="T_cf3ac_row4_col3" class="data row4 col3" >23,090</td>
#                         <td id="T_cf3ac_row4_col4" class="data row4 col4" >206,462</td>
#                         <td id="T_cf3ac_row4_col5" class="data row4 col5" >40,867,856</td>
#                         <td id="T_cf3ac_row4_col6" class="data row4 col6" >2,269</td>
#                         <td id="T_cf3ac_row4_col7" class="data row4 col7" >10%</td>
#             </tr>
#             <tr>
#                         <th id="T_cf3ac_level0_row5" class="row_heading level0 row5" >South America</th>
#                         <td id="T_cf3ac_row5_col0" class="data row5 col0" >12</td>
#                         <td id="T_cf3ac_row5_col1" class="data row5 col1" >433,950,159</td>
#                         <td id="T_cf3ac_row5_col2" class="data row5 col2" >30</td>
#                         <td id="T_cf3ac_row5_col3" class="data row5 col3" >13,841</td>
#                         <td id="T_cf3ac_row5_col4" class="data row5 col4" >38,136,842</td>
#                         <td id="T_cf3ac_row5_col5" class="data row5 col5" >482,815,312</td>
#                         <td id="T_cf3ac_row5_col6" class="data row5 col6" >1,164,783</td>
#                         <td id="T_cf3ac_row5_col7" class="data row5 col7" >8%</td>
#             </tr>
#     </tbody></table>

# %%
high_low_gdp = clean_data.nlargest(5,"gdp_per_capita")
high_low_gdp = high_low_gdp.append(clean_data.nsmallest(5,"gdp_per_capita"))
high_low_gdp = high_low_gdp.sort_values(by="gdp_per_capita", ascending=False)

high_low_gdp = high_low_gdp.rename(columns={
"population":"Population",
"median_age":"Median Age",
"gdp_per_capita": "Average GDP/capita",
"total_cases":"Total Cases",
"total_vaccinations":"Total Vaccinations",
"total_deaths":"Total Deaths",
"diabetes_prevalence":"Diabetes Prevalance"})

# %%
#GDP/capita vs Total Cases/capita

#dataframe
gdp_v_total_cases = clean_data[["location","gdp_per_capita","total_cases","population"]]
gdp_v_total_cases = gdp_v_total_cases.set_index(gdp_v_total_cases["location"])
gdp_v_total_cases

#linear regression
cases_slp, cases_int, cases_r, cases_p, cases_std = linregress(gdp_v_total_cases["gdp_per_capita"],
                                                               gdp_v_total_cases["total_cases"]/gdp_v_total_cases["population"])
cases_fit = cases_slp * gdp_v_total_cases["gdp_per_capita"] + cases_int

#Scatter plot
plt.scatter(gdp_v_total_cases["gdp_per_capita"],
            gdp_v_total_cases["total_cases"]/gdp_v_total_cases["population"])
plt.ylabel("Total cases per Capita")
plt.xlabel("GDP per Capita")
plt.title("GDP vs Total Cases (per capita)")
plt.plot(gdp_v_total_cases["gdp_per_capita"], cases_fit, "r-")
plt.savefig("Output/Cases_Scatter.png")
plt.show()

print(f"The r-value is: {cases_r}")
print(f"The p-value is: {cases_p}")

#Spearman R
case_corr, _ = spearmanr(clean_data["gdp_per_capita"], clean_data["total_cases"])
print(f'Spearmans correlation is: {case_corr}')
# Out:
# The r-value is: 0.3865399384772331
# The p-value is: 4.4485616943801715e-07
# Spearmans correlation is: 0.4023877885854916

# %%
#Bar graph for total cases of 5 hightest and lowest GDPs
custom_lines = [Line2D([0], [0], color="b", lw=4),
                Line2D([0], [0], color="g", lw=4)]
colors = ["b","b","b","b","b","g","g","g","g","g",]
high_low_gdp.plot.bar(x="location", y="Total Cases", color=colors)
plt.suptitle("Total Cases vs GDP/capita", fontdict={"fontsize":14})
plt.title("For Countries w/ 5 Highest and 5 Lowest GDP/capita",fontdict={"fontsize":10})
plt.legend(custom_lines, ["High GDP", "Low GDP"])
plt.xlabel("Country")
plt.ylabel("Total Cases")
plt.savefig("Output/Cases_Bar.png")
plt.show()

# %%
#GDP/capita vs Vaccinations/capita

#dataframe
gdp_v_total_vaccinations = clean_data[["location","gdp_per_capita","total_vaccinations","population"]]
gdp_v_total_vaccinations = gdp_v_total_vaccinations.set_index(gdp_v_total_cases["location"])
gdp_v_total_vaccinations

#linear regression
vax_slp, vax_int, vax_r, vax_p, vax_std = linregress(gdp_v_total_vaccinations["gdp_per_capita"],
                                                               gdp_v_total_vaccinations["total_vaccinations"]/gdp_v_total_vaccinations["population"])
vax_fit = vax_slp * gdp_v_total_vaccinations["gdp_per_capita"] + vax_int

#Scatter plot
plt.scatter(gdp_v_total_vaccinations["gdp_per_capita"],
            gdp_v_total_vaccinations["total_vaccinations"]/gdp_v_total_vaccinations["population"])
plt.ylabel("Total Vaccinations per Capita")
plt.xlabel("GDP per Capita")
plt.title("GDP vs Total Vaccinations (per capita)")
plt.plot(gdp_v_total_vaccinations["gdp_per_capita"], vax_fit, "r-")
plt.savefig("Output/Vax_Scatter.png")
plt.show()

print(f"The r-value is: {vax_r}")
print(f"The p-value is: {vax_p}")

#Spearman R
vax_corr, _ = spearmanr(clean_data["gdp_per_capita"], clean_data["total_vaccinations"])
print(f'Spearmans correlation is: {vax_corr}')
# Out:
# The r-value is: 0.7007688655670645
# The p-value is: 6.0130403396967485e-25
# Spearmans correlation is: 0.4066945974452127

# %%
#Bar graph for total vaccinations of 5 hightest and lowest GDPs
high_low_gdp.plot.bar(x="location", y="Total Vaccinations", color=colors )
plt.suptitle("Total Vaccinations vs GDP/capita", fontdict={"fontsize":14})
plt.title("For Countries w/ 5 Highest and 5 Lowest GDP/capita",fontdict={"fontsize":10})
plt.xlabel("Country")
plt.ylabel("Total Vaccinations")
plt.legend(custom_lines, ["High GDP", "Low GDP"])
plt.savefig("Output/Vax_Bar.png")
plt.show()

# %%
#GDP/capita vs Total Deaths/capita

#dataframe
gdp_v_total_deaths = clean_data[["location","gdp_per_capita","total_deaths","population"]]
gdp_v_total_deaths = gdp_v_total_deaths.set_index(gdp_v_total_deaths["location"])
gdp_v_total_deaths

#linear regression
death_slp, death_int, death_r, death_p, death_std = linregress(gdp_v_total_deaths["gdp_per_capita"],
                                                               gdp_v_total_deaths["total_deaths"]/gdp_v_total_deaths["population"])
death_fit = death_slp * gdp_v_total_deaths["gdp_per_capita"] + death_int

#Scatter plot
plt.scatter(gdp_v_total_deaths["gdp_per_capita"],
            gdp_v_total_deaths["total_deaths"]/gdp_v_total_deaths["population"])
plt.ylabel("Total Deaths per Capita")
plt.xlabel("GDP per Capita")
plt.title("GDP vs Total Death (per capita)")
plt.plot(gdp_v_total_deaths["gdp_per_capita"], death_fit, "r-")
plt.savefig("Output/Deaths_Scatter.png")
plt.show()

print(f"The r-value is: {death_r}")
print(f"The p-value is: {death_p}")

#Spearman R
deaths_corr, _ = spearmanr(clean_data["gdp_per_capita"], clean_data["total_deaths"])
print(f'Spearmans correlation is: {deaths_corr}')
# Out:
# The r-value is: 0.14346408860619608
# The p-value is: 0.0703208294890451
# Spearmans correlation is: 0.2828231926568251

# %%
#Bar graph for total deaths of 5 hightest and lowest GDPs
high_low_gdp.plot.bar(x="location", y="Total Deaths", color=colors)
plt.suptitle("Total Deaths vs GDP/capita", fontdict={"fontsize":14})
plt.title("For Countries w/ 5 Highest and 5 Lowest GDP/capita",fontdict={"fontsize":10})
plt.xlabel("Country")
plt.ylabel("Total Deaths")
plt.legend(custom_lines, ["High GDP", "Low GDP"])
plt.savefig("Output/Deaths_bar.png")
plt.show()
